# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

# %%
image = cv.imread("download.jfif")
image1 = cv.imread("download.jfif")

# %%
imag = plt.imshow(image)

# %%
#Applying pseudocolor schemes to image plots
lum_img1 = image[:, :, 0]
plt.imshow(lum_img1)

# %%
plt.imshow(lum_img1, cmap="hot")

# %%
image.shape
# Out:
# (194, 259, 3)

# %%
corner=image[0:100,0:100]

# %%
plt.imshow(corner)

# %%
# Image Translation
#The first row of the matrix is [1, 0, tx], where tx is the number of pixels we will shift the image left or right. 
#Negative values of tx will shift the image to the left and positive values will shift the image to the right
M = np.float32([[1,0, 25], [0, 1, 50]])
print(image.shape[0])
print(image.shape[1])
shifted = cv.warpAffine(image, M, (image.shape[1], image.shape[0]))
plt.imshow(shifted)
# Out:
# 194
# 259

# %%
# Rotation
plt.imshow(image)

(h, w) = image.shape[:2]
#h=image.shape[0]
#w=image.shape[1]

center = (w // 2, h // 2)
M = cv.getRotationMatrix2D(center, 45, 1.0)
rotated = cv.warpAffine(image, M, (w, h))
print("Rotated by 45 Degrees")
plt.imshow(rotated)
# Out:
# Rotated by 45 Degrees

# %%
print(image.shape)

r = 150.0 / image.shape[1]
dim = (150, int(image.shape[0] * r))
resized = cv.resize(image, dim, interpolation = cv.INTER_AREA)
print(resized.shape)
plt.imshow(resized)

# res = cv.resize(img,None,fx=2, fy=2, interpolation = cv.INTER_CUBIC)
#OR
# height, width = img.shape[:2]
# res = cv.resize(img,(2*width, 2*height), interpolation = cv.INTER_CUBIC)
# plt.imshow(res[:, :, ::-1])
# Out:
# (194, 259, 3)
# (112, 150, 3)

# %%
plt.imshow(image)
flipped = cv.flip(image, 0)
plt.imshow(flipped)

# %%
i_gray = cv.cvtColor(image1, cv.COLOR_BGR2GRAY) #BGR to gray conversion
plt.imshow(i_gray)

# %%
i_rgb = cv.cvtColor(image1, cv.COLOR_BGR2RGB) #BGR to RGB (useful for matplotlib)
plt.imshow(i_rgb)

# %%
i = cv.normalize(image, None, 0, 255, cv.NORM_MINMAX, cv.CV_8U) #Normalizes I between 0 and 255
plt.imshow(i)

# %%
canvas = np.zeros((300, 300, 3), dtype = "uint8")
#RGB(255,255,255)
green = (0, 255, 0)
cv.line(canvas, (0, 0), (300, 300), green,4)
plt.imshow(canvas)

# %%
red = (255, 0, 0)
cv.line(canvas, (300, 0), (0, 300), red, 3)
plt.imshow(canvas)
cv.waitKey(0)
# Out:
# -1
